# %% [markdown]
# # BPL_TEST2_Batch - demo

# %%
# Import the application model and context variables
from BPL_TEST2_Batch_pyfmi import*
# Out:
# Windows - run FMU pre-compiled JModelica 2.14

# %%
# Import the general FMU_explore functions ana adapt them to the application
from fmu_explore_pyfmi import AdaptWith

Adapted = AdaptWith(parValue, parLocation, parCheck, \
                    model, fmu_model, fmu_process_diagram, \
                    MSL_usage, MSL_version, BPL_version, \
                    opts_std, simulationTime, timeDiscreteStates, \
                    diagrams, ax, lines)

par = Adapted.par
init = Adapted.init
disp = Adapted.disp
simu = Adapted.simu
show = Adapted.show

resetPen = Adapted.resetPen
process_diagram = Adapted.process_diagram
describe_general = Adapted.describe_general
describe_parts = Adapted.describe_parts
describe_MSL = Adapted.describe_MSL
FMU_explore_info = Adapted.FMU_explore_info
system_info = Adapted.system_info
SDG = Adapted.SDG
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 # Import the general FMU_explore functions ana adapt them to the application
#       2 from fmu_explore_pyfmi import AdaptWith
# ----> 4 Adapted = AdaptWith(parValue, parLocation, parCheck, \
#       5                     model, fmu_model, fmu_process_diagram, \
#       6                     MSL_usage, MSL_version, BPL_version, \
#       7                     opts_std, simulationTime, timeDiscreteStates, \
#       8 #                   diagrams, ax, lines, \
#       9                     )
#      11 par = Adapted.par
#      12 init = Adapted.init
#
# TypeError: AdaptWith.__init__() missing 3 required positional arguments: 'diagrams', 'ax', and 'lines'

# %%
# Bring in the user made fmu_explore functions newplot() and describe()

# %%
run -i BPL_TEST2_Batch_explore.py

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [25/2.54, 20/2.54]

# %%
process_diagram()

# %%
describe('process')

# %%
describe('culture')

# %% [markdown]
# disp('bioreactor', mode='long')

# %%
# Simulation with default values of the process
newplot(plotType='TimeSeries')
simu()

# %%
# Simulation were initial value of biomass VX_0 is varied
newplot(plotType='TimeSeries') 
for value in [1.0, 0.7, 1.3]: init(VX_start=value); simu(5)

# Restore default value of VX_0
init(VX_start=1.0)

# %%
# Simulation were initial value of substrate VS_start is varied
newplot(plotType='TimeSeries') 
for value in [10, 7, 13]: init(VS_start=value); simu(5)

# Restore default value of VS_start
init(VS_start=10)

# %%
# Simulation where metabolism is changed after 3 hours
newplot(plotType='TimeSeries') 
simu(5)

simu(3)
par(Y=0.4, qSmax=1.0/(0.4/0.5)); simu(2, 'cont')

# Restore default value of Y and qSmax
par(Y=0.5, qSmax=1.0)

# %%
disp('culture')

# %%
describe('mu')

# %%
describe('parts')

# %%
describe('MSL')

# %%
system_info()

# %%
SDG('explan')

# %%
Adapted.lines

# %%
Adapted.ax

# %%
newplot()
Adapted.ax

# %%
Adapted.diagrams

# %%
import fmu_explore

# %%
import fmu_explore_pyfmi

# %%
fmu_explore_pyfmi.__version__
